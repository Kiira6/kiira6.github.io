# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiira6/kiira6.github.io/blob/master/AutoEncoder_RAW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import fnmatch

def find_mp3_files(directory):
    # Lista para almacenar las rutas de los archivos .mp3
    mp3_files = []

    # Recorrer el directorio y subdirectorios
    for dirpath, dirnames, filenames in os.walk(directory):
        for filename in filenames:
            # Si el archivo es .mp3, agregarlo a la lista
            if fnmatch.fnmatch(filename, '*.mp3'):
                mp3_files.append(os.path.join(dirpath, filename))

    return mp3_files

# %%
# Solicitamos al usuario la ruta donde buscar los archivos mp3
directory = "D:\ProyectoLibertad\mp3"

mp3_files = find_mp3_files(directory)

len(mp3_files)
# Out:
# 119355

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size=3, padding=1)
        self.norm1 = nn.BatchNorm1d(out_channels)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size=3, padding=1)
        self.norm2 = nn.BatchNorm1d(out_channels)
        self.skip = nn.Conv1d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        residual = self.skip(x)
        x = F.relu(self.norm1(self.conv1(x)))
        x = self.norm2(self.conv2(x))
        return F.relu(x + residual)

class Encoder(nn.Module):
    def __init__(self, C, B, K, S, D):
        super(Encoder, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=C, kernel_size=7, padding=3)
        self.norm1 = nn.BatchNorm1d(C)
        self.blocks = nn.ModuleList([ResidualBlock(C*(2**i), C*(2**(i+1))) for i in range(B)])
        self.lstm = nn.LSTM(input_size=C*(2**B), hidden_size=D, num_layers=2)
        self.conv2 = nn.Conv1d(in_channels=D, out_channels=D, kernel_size=7, padding=3)
        self.norm2 = nn.BatchNorm1d(D)

    def forward(self, x):
        x = F.relu(self.norm1(self.conv1(x)))
        for block in self.blocks:
            x = block(x)
        x, _ = self.lstm(x)
        x = F.relu(self.norm2(self.conv2(x)))
        return x

class Decoder(nn.Module):
    def __init__(self, C, B, K, S, D):
        super(Decoder, self).__init__()
        self.conv1 = nn.ConvTranspose1d(in_channels=D, out_channels=D, kernel_size=7, padding=3)
        self.norm1 = nn.BatchNorm1d(D)
        self.blocks = nn.ModuleList([ResidualBlock(C*(2**(B-i)), C*(2**(B-i-1))) for i in range(B)])
        self.lstm = nn.LSTM(input_size=C, hidden_size=D, num_layers=2)
        self.conv2 = nn.ConvTranspose1d(in_channels=D, out_channels=1, kernel_size=7, padding=3)

    def forward(self, x):
        x = F.relu(self.norm1(self.conv1(x)))
        for block in reversed(self.blocks):
            x = block(x)
        x, _ = self.lstm(x)
        x = self.conv2(x)
        return x

class RVQ(nn.Module):
    def __init__(self, D, num_embeddings, num_residuals):
        super(RVQ, self).__init__()
        self.embeddings = nn.ModuleList([nn.Embedding(num_embeddings, D) for _ in range(num_residuals)])

    def forward(self, x):
        x = x.permute(0, 2, 1).contiguous()
        x_shape = x.shape
        flat_input = x.view(-1, x_shape[-1])
        residuals = []
        for embedding in self.embeddings:
            distances = (torch.sum(flat_input**2, dim=1, keepdim=True)
                        + torch.sum(embedding.weight**2, dim=1)
                        - 2 * torch.matmul(flat_input, embedding.weight.t()))
            encoding_indices = torch.argmin(distances, dim=1).unsqueeze(1)
            encodings = torch.zeros(encoding_indices.shape[0], embedding.weight.shape[0]).to(x.device)
            encodings.scatter_(1, encoding_indices, 1)
            quantized = embedding(encoding_indices).view(*x_shape)
            residuals.append(quantized)
            flat_input = flat_input - quantized.view(-1, x_shape[-1])
        return sum(residuals).permute(0, 2, 1).contiguous(), encodings, encoding_indices

class EnCodec(nn.Module):
    def __init__(self, C, B, K, S, D, num_embeddings, num_residuals):
        super(EnCodec, self).__init__()
        self.encoder = Encoder(C, B, K, S, D)
        self.rvq = RVQ(D, num_embeddings, num_residuals)
        self.decoder = Decoder(C, B, K, S, D)

    def forward(self, x):
        x = self.encoder(x)
        x, encodings, encoding_indices = self.rvq(x)
        x = self.decoder(x)
        return x, encodings, encoding_indices

    def loss(self, x, target, encodings):
        reconstruction_loss = F.mse_loss(x, target)
        commitment_loss = F.mse_loss(encodings, torch.ones_like(encodings).to(x.device))
        return reconstruction_loss + commitment_loss

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

def visualize_audio(path):
    # Cargar el archivo de audio
    y, sr = librosa.load(path)

    # Visualizar la onda sinusoidal
    plt.figure(figsize=(14, 5))
    librosa.display.waveshow(y, sr=sr)
    plt.title('Waveplot')
    plt.show()

    # Calcular el MFCC
    mfccs = librosa.feature.mfcc(y=y, sr=sr)

    # Visualizar el MFCC
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(mfccs, sr=sr, x_axis='time')
    plt.colorbar()
    plt.title('MFCC')
    plt.show()

def visualize_sinewave(sinewave, sr = 22050):

    # Visualizar la onda sinusoidal
    plt.figure(figsize=(14, 5))
    librosa.display.waveshow(sinewave, sr=sr)
    plt.title('Waveplot')
    plt.show()

    # Calcular el MFCC
    mfccs = librosa.feature.mfcc(y=sinewave, sr=sr)

    # Visualizar el MFCC
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(mfccs, sr=sr, x_axis='time')
    plt.colorbar()
    plt.title('MFCC')
    plt.show()

# Uso de la función
#visualize_audio('/content/1 - ABBA - Super Trouper.mp3')

# %%
import torch
from torch import nn

class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid(),  # To ensure the output is in the range [0, 1]
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

    def encode(self, x):
      return self.encoder(x)

    def decode(self, x):
      return self.decoder(x)

# %%
import pytorch_lightning as pl
import torchaudio

class AutoEncoderModule(pl.LightningModule):
    def __init__(self):
        super(AutoEncoderModule, self).__init__()
        self.autoencoder = AutoEncoder()

    def forward(self, x):
        return self.autoencoder(x)

    def save_decoded_audio(self, decoded_waveform, sample_rate, filename):
        """
        Save the decoded waveform as an audio file.

        Args:
            decoded_waveform (torch.Tensor): The decoded waveform to save. Should be of shape (n_channels, n_time_steps).
            sample_rate (int): The sample rate for the audio file.
            filename (str): The name of the file to save the audio as.
        """

        mono_tensor = decoded_waveform.squeeze(0)
        mono_tensor = mono_tensor.detach()
        mono_tensor = mono_tensor.sum(dim=0, keepdim=True)
        torchaudio.save(filename, decoded_waveform[0], sample_rate)

    def training_step(self, batch, batch_idx):
        x = batch

        # MFCC transform
        mfcc_transform = torchaudio.transforms.MFCC(sample_rate=22050, n_mfcc=128).to(x.device)
        y_mfcc = mfcc_transform(x)

        # Autoencoder output
        z = self.autoencoder(x)
        z = z[:, :, :22050*180]
        z_mfcc = mfcc_transform(z)

        # Log-Mel Spectrogram transform
        mel_transform = torchaudio.transforms.MelSpectrogram(sample_rate=22050, n_mels=40).to(x.device)
        log_mel_transform = torchaudio.transforms.AmplitudeToDB().to(x.device)
        y_log_mel = log_mel_transform(mel_transform(x))
        z_log_mel = log_mel_transform(mel_transform(z))

        # Loss calculation
        loss_mfcc = nn.MSELoss()(z_mfcc, y_mfcc)
        loss_waveform = nn.MSELoss()(z, x)
        #loss_log_mel = nn.MSELoss()(z_log_mel, y_log_mel)
        loss = loss_mfcc + loss_waveform # + loss_log_mel

        self.log('train_loss', loss)
        print('\ntrain_loss:', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x = batch

        # MFCC transform
        mfcc_transform = torchaudio.transforms.MFCC(sample_rate=22050, n_mfcc=128).to(x.device)
        y_mfcc = mfcc_transform(x)

        # Autoencoder output
        z = self.autoencoder(x)
        z = z[:, :, :22050*180]
        z_mfcc = mfcc_transform(z)

        # Log-Mel Spectrogram transform
        mel_transform = torchaudio.transforms.MelSpectrogram(sample_rate=22050, n_mels=40).to(x.device)
        log_mel_transform = torchaudio.transforms.AmplitudeToDB().to(x.device)
        y_log_mel = log_mel_transform(mel_transform(x))
        z_log_mel = log_mel_transform(mel_transform(z))

        # Loss calculation
        loss_mfcc = nn.MSELoss()(z_mfcc, y_mfcc)
        loss_waveform = nn.MSELoss()(z, x)
        #loss_log_mel = nn.MSELoss()(z_log_mel, y_log_mel)
        loss = loss_mfcc + loss_waveform # + loss_log_mel

        self.log('val_loss', loss)
        print('\nval_loss:', loss)
        return loss


    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

# %%
from torch.utils.data import Dataset
import os
import torchaudio
import torch.nn.functional as F

class AudioDataset(Dataset):
    def __init__(self, audio_paths, max_length=22050*180):
        self.file_list = audio_paths
        self.max_length = max_length

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        audio_name = self.file_list[idx]
        waveform, sample_rate = torchaudio.load(audio_name)
        # Convert to mono by averaging the channels
        #waveform = waveform.mean(dim=0, keepdim=True)
        waveform = torch.mean(waveform, dim=0, keepdim=True)  # Convert to mono
        waveform = waveform[:, :self.max_length]

        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=22050)
        waveform = resampler(waveform)
        #mfcc_transform = torchaudio.transforms.MFCC(sample_rate=22050)
        #mfcc = mfcc_transform(waveform)
        waveform = waveform[:, :self.max_length]

        # Pad or truncate the waveform to a fixed length
        if waveform.size(1) < self.max_length:
            padding = torch.zeros((waveform.size(0), self.max_length - waveform.size(1)))
            waveform = torch.cat((waveform, padding), dim=1)

        return waveform

# %%
def collate_fn(batch):
    print([audio.shape for audio, _ in batch])

    # Find the maximum length audio in the batch
    max_length = max(audio.shape[1] for audio, _ in batch)

    # Create tensors to hold the padded audios and labels
    audios = torch.zeros(len(batch), 1, max_length)
    labels = torch.zeros(len(batch), 9117)  # replace `label_length` with the length of your labels

    # Pad the audios and get the labels
    for i, (audio, label) in enumerate(batch):
        audios[i, :, :audio.shape[1]] = audio
        labels = torch.zeros(len(batch), 9117)
        labels[i, :] = label

    return audios, labels

# %%
import random
from torch.utils.data import random_split
from torch.utils.data import DataLoader

n = 1000  # Número de elementos que quieres seleccionar
random_files = random.sample(mp3_files, n)

# Crear el conjunto de datos completo
dataset = AudioDataset(random_files)

# Determinar los tamaños de los conjuntos de entrenamiento y prueba
train_size = int(0.8 * len(dataset))  # 80% para entrenamiento
test_size = len(dataset) - train_size  # 20% para prueba

# Dividir el conjunto de datos
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# Crear los DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=True)

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

# Define un ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    # Ruta donde se guardarán los checkpoints
    dirpath='C:\\ProyectoLibertad\\autoencoder\\checkpoints',
    # Nombre del archivo del checkpoint
    filename='autoencoder-{epoch:02d}-{val_loss:.2f}',
    # Guarda un checkpoint cada X épocas
    every_n_epochs=1,
    # Guarda solo los K mejores modelos
    save_top_k=1000,
    # Métrica de validación para determinar cuáles son los mejores modelos
    monitor='val_loss',
    # Modo del monitor ('min' para pérdida, 'max' para precisión, etc.)
    mode='min',
)

# %%
from pytorch_lightning import Trainer

torch.set_float32_matmul_precision('medium')
#model = AutoEncoderModule()
trainer = Trainer(max_epochs=300, callbacks=[checkpoint_callback])

# Pasar los dataloaders al método fit()
trainer.fit(model2, train_dataloader, val_dataloaders=test_dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name        | Type        | Params
# --------------------------------------------
# 0 | autoencoder | AutoEncoder | 784 K
# --------------------------------------------
# 784 K     Trainable params
# 0         Non-trainable params
# 784 K     Total params
# 3.138     Total estimated model params size (MB)
# Se han truncado las últimas 5000 líneas del flujo de salida.
# train_loss: tensor(24.9295, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  28%|████████████████▌                                          | 224/800 [51:53<2:13:25, 13.90s/it, v_num=75]
# train_loss: tensor(18.0926, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  28%|████████████████▌                                          | 225/800 [52:07<2:13:12, 13.90s/it, v_num=75]
# train_loss: tensor(10.9250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  28%|████████████████▋                                          | 226/800 [52:21<2:12:58, 13.90s/it, v_num=75]
# train_loss: tensor(20.0756, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  28%|████████████████▋                                          | 227/800 [52:35<2:12:45, 13.90s/it, v_num=75]
# train_loss: tensor(12.6043, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  28%|████████████████▊                                          | 228/800 [52:49<2:12:31, 13.90s/it, v_num=75]
# train_loss: tensor(11.7807, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|████████████████▉                                          | 229/800 [53:03<2:12:18, 13.90s/it, v_num=75]
# train_loss: tensor(37.6225, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|████████████████▉                                          | 230/800 [53:17<2:12:04, 13.90s/it, v_num=75]
# train_loss: tensor(13.4112, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|█████████████████                                          | 231/800 [53:31<2:11:50, 13.90s/it, v_num=75]
# train_loss: tensor(13.4712, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|█████████████████                                          | 232/800 [53:45<2:11:37, 13.90s/it, v_num=75]
# train_loss: tensor(12.7445, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|█████████████████▏                                         | 233/800 [53:59<2:11:23, 13.90s/it, v_num=75]
# train_loss: tensor(11.4639, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|█████████████████▎                                         | 234/800 [54:13<2:11:10, 13.91s/it, v_num=75]
# train_loss: tensor(31.1152, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  29%|█████████████████▎                                         | 235/800 [54:27<2:10:56, 13.91s/it, v_num=75]
# train_loss: tensor(12.0676, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▍                                         | 236/800 [54:42<2:10:43, 13.91s/it, v_num=75]
# train_loss: tensor(16.7542, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▍                                         | 237/800 [54:56<2:10:29, 13.91s/it, v_num=75]
# train_loss: tensor(12.2535, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▌                                         | 238/800 [55:10<2:10:16, 13.91s/it, v_num=75]
# train_loss: tensor(10.3932, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▋                                         | 239/800 [55:23<2:10:02, 13.91s/it, v_num=75]
# train_loss: tensor(9.6507, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▋                                         | 240/800 [55:37<2:09:48, 13.91s/it, v_num=75]
# train_loss: tensor(18.4170, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▊                                         | 241/800 [55:51<2:09:34, 13.91s/it, v_num=75]
# train_loss: tensor(18.7516, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▊                                         | 242/800 [56:05<2:09:19, 13.91s/it, v_num=75]
# train_loss: tensor(15.1955, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▉                                         | 243/800 [56:18<2:09:05, 13.90s/it, v_num=75]
# train_loss: tensor(17.9335, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  30%|█████████████████▉                                         | 244/800 [56:32<2:08:50, 13.90s/it, v_num=75]
# train_loss: tensor(12.3923, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████                                         | 245/800 [56:46<2:08:35, 13.90s/it, v_num=75]
# train_loss: tensor(18.8889, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████▏                                        | 246/800 [56:59<2:08:20, 13.90s/it, v_num=75]
# train_loss: tensor(36.5246, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████▏                                        | 247/800 [57:13<2:08:06, 13.90s/it, v_num=75]
# train_loss: tensor(12.8010, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████▎                                        | 248/800 [57:26<2:07:51, 13.90s/it, v_num=75]
# train_loss: tensor(9.2605, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████▎                                        | 249/800 [57:40<2:07:37, 13.90s/it, v_num=75]
# train_loss: tensor(9.8564, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████▍                                        | 250/800 [57:53<2:07:22, 13.90s/it, v_num=75]
# train_loss: tensor(9.9749, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  31%|██████████████████▌                                        | 251/800 [58:07<2:07:08, 13.90s/it, v_num=75]
# train_loss: tensor(10.4137, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▌                                        | 252/800 [58:21<2:06:54, 13.90s/it, v_num=75]
# train_loss: tensor(15.5635, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▋                                        | 253/800 [58:35<2:06:39, 13.89s/it, v_num=75]
# train_loss: tensor(15.3699, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▋                                        | 254/800 [58:48<2:06:25, 13.89s/it, v_num=75]
# train_loss: tensor(14.0317, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▊                                        | 255/800 [59:02<2:06:10, 13.89s/it, v_num=75]
# train_loss: tensor(10.9924, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▉                                        | 256/800 [59:15<2:05:55, 13.89s/it, v_num=75]
# train_loss: tensor(14.2669, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▉                                        | 257/800 [59:29<2:05:41, 13.89s/it, v_num=75]
# train_loss: tensor(18.9178, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|███████████████████                                        | 258/800 [59:42<2:05:26, 13.89s/it, v_num=75]
# train_loss: tensor(12.6669, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|███████████████████                                        | 259/800 [59:56<2:05:12, 13.89s/it, v_num=75]
# train_loss: tensor(13.4887, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  32%|██████████████████▌                                      | 260/800 [1:00:10<2:04:58, 13.89s/it, v_num=75]
# train_loss: tensor(14.9936, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|██████████████████▌                                      | 261/800 [1:00:23<2:04:43, 13.88s/it, v_num=75]
# train_loss: tensor(8.9485, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|██████████████████▋                                      | 262/800 [1:00:37<2:04:29, 13.88s/it, v_num=75]
# train_loss: tensor(14.5039, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|██████████████████▋                                      | 263/800 [1:00:50<2:04:14, 13.88s/it, v_num=75]
# train_loss: tensor(10.7669, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|██████████████████▊                                      | 264/800 [1:01:04<2:04:00, 13.88s/it, v_num=75]
# train_loss: tensor(13.0133, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|██████████████████▉                                      | 265/800 [1:01:18<2:03:46, 13.88s/it, v_num=75]
# train_loss: tensor(10.0175, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|██████████████████▉                                      | 266/800 [1:01:32<2:03:32, 13.88s/it, v_num=75]
# train_loss: tensor(11.9332, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  33%|███████████████████                                      | 267/800 [1:01:46<2:03:19, 13.88s/it, v_num=75]
# train_loss: tensor(24.8051, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████                                      | 268/800 [1:02:00<2:03:05, 13.88s/it, v_num=75]
# train_loss: tensor(10.4251, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▏                                     | 269/800 [1:02:14<2:02:52, 13.88s/it, v_num=75]
# train_loss: tensor(13.8468, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▏                                     | 270/800 [1:02:28<2:02:38, 13.88s/it, v_num=75]
# train_loss: tensor(14.9560, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▎                                     | 271/800 [1:02:42<2:02:25, 13.89s/it, v_num=75]
# train_loss: tensor(17.6090, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▍                                     | 272/800 [1:02:56<2:02:11, 13.89s/it, v_num=75]
# train_loss: tensor(9.5512, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▍                                     | 273/800 [1:03:10<2:01:58, 13.89s/it, v_num=75]
# train_loss: tensor(11.7590, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▌                                     | 274/800 [1:03:24<2:01:44, 13.89s/it, v_num=75]
# train_loss: tensor(10.2252, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▌                                     | 275/800 [1:03:38<2:01:30, 13.89s/it, v_num=75]
# train_loss: tensor(10.0012, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  34%|███████████████████▋                                     | 276/800 [1:03:53<2:01:17, 13.89s/it, v_num=75]
# train_loss: tensor(19.2750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|███████████████████▋                                     | 277/800 [1:04:07<2:01:03, 13.89s/it, v_num=75]
# train_loss: tensor(10.8501, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|███████████████████▊                                     | 278/800 [1:04:21<2:00:50, 13.89s/it, v_num=75]
# train_loss: tensor(14.3946, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|███████████████████▉                                     | 279/800 [1:04:35<2:00:36, 13.89s/it, v_num=75]
# train_loss: tensor(9.3176, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|███████████████████▉                                     | 280/800 [1:04:49<2:00:23, 13.89s/it, v_num=75]
# train_loss: tensor(23.8362, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|████████████████████                                     | 281/800 [1:05:03<2:00:09, 13.89s/it, v_num=75]
# train_loss: tensor(12.2236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|████████████████████                                     | 282/800 [1:05:17<1:59:55, 13.89s/it, v_num=75]
# train_loss: tensor(34.4142, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  35%|████████████████████▏                                    | 283/800 [1:05:30<1:59:40, 13.89s/it, v_num=75]
# train_loss: tensor(15.7015, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▏                                    | 284/800 [1:05:44<1:59:27, 13.89s/it, v_num=75]
# train_loss: tensor(24.1886, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▎                                    | 285/800 [1:05:58<1:59:13, 13.89s/it, v_num=75]
# train_loss: tensor(14.0526, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▍                                    | 286/800 [1:06:12<1:58:58, 13.89s/it, v_num=75]
# train_loss: tensor(15.1566, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▍                                    | 287/800 [1:06:25<1:58:44, 13.89s/it, v_num=75]
# train_loss: tensor(16.9217, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▌                                    | 288/800 [1:06:39<1:58:30, 13.89s/it, v_num=75]
# train_loss: tensor(32.7404, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▌                                    | 289/800 [1:06:52<1:58:15, 13.89s/it, v_num=75]
# train_loss: tensor(9.1140, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▋                                    | 290/800 [1:07:06<1:58:01, 13.88s/it, v_num=75]
# train_loss: tensor(8.4791, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▋                                    | 291/800 [1:07:19<1:57:46, 13.88s/it, v_num=75]
# train_loss: tensor(9.3074, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  36%|████████████████████▊                                    | 292/800 [1:07:33<1:57:32, 13.88s/it, v_num=75]
# train_loss: tensor(11.5788, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|████████████████████▉                                    | 293/800 [1:07:47<1:57:17, 13.88s/it, v_num=75]
# train_loss: tensor(13.4475, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|████████████████████▉                                    | 294/800 [1:08:01<1:57:04, 13.88s/it, v_num=75]
# train_loss: tensor(14.4419, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|█████████████████████                                    | 295/800 [1:08:15<1:56:50, 13.88s/it, v_num=75]
# train_loss: tensor(8.6632, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|█████████████████████                                    | 296/800 [1:08:28<1:56:36, 13.88s/it, v_num=75]
# train_loss: tensor(14.8925, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|█████████████████████▏                                   | 297/800 [1:08:42<1:56:21, 13.88s/it, v_num=75]
# train_loss: tensor(17.9013, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|█████████████████████▏                                   | 298/800 [1:08:55<1:56:07, 13.88s/it, v_num=75]
# train_loss: tensor(14.6219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  37%|█████████████████████▎                                   | 299/800 [1:09:09<1:55:53, 13.88s/it, v_num=75]
# train_loss: tensor(11.9687, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▍                                   | 300/800 [1:09:23<1:55:38, 13.88s/it, v_num=75]
# train_loss: tensor(17.4726, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▍                                   | 301/800 [1:09:36<1:55:24, 13.88s/it, v_num=75]
# train_loss: tensor(16.5748, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▌                                   | 302/800 [1:09:50<1:55:10, 13.88s/it, v_num=75]
# train_loss: tensor(11.9116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▌                                   | 303/800 [1:10:04<1:54:56, 13.88s/it, v_num=75]
# train_loss: tensor(12.8063, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▋                                   | 304/800 [1:10:17<1:54:41, 13.87s/it, v_num=75]
# train_loss: tensor(14.0158, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▋                                   | 305/800 [1:10:31<1:54:27, 13.87s/it, v_num=75]
# train_loss: tensor(12.6106, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▊                                   | 306/800 [1:10:45<1:54:13, 13.87s/it, v_num=75]
# train_loss: tensor(12.4453, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▊                                   | 307/800 [1:10:58<1:53:58, 13.87s/it, v_num=75]
# train_loss: tensor(10.6525, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  38%|█████████████████████▉                                   | 308/800 [1:11:12<1:53:44, 13.87s/it, v_num=75]
# train_loss: tensor(15.6266, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████                                   | 309/800 [1:11:25<1:53:30, 13.87s/it, v_num=75]
# train_loss: tensor(11.1197, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████                                   | 310/800 [1:11:39<1:53:15, 13.87s/it, v_num=75]
# train_loss: tensor(10.5218, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████▏                                  | 311/800 [1:11:53<1:53:01, 13.87s/it, v_num=75]
# train_loss: tensor(71.4356, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████▏                                  | 312/800 [1:12:06<1:52:47, 13.87s/it, v_num=75]
# train_loss: tensor(8.1841, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████▎                                  | 313/800 [1:12:20<1:52:33, 13.87s/it, v_num=75]
# train_loss: tensor(9.8590, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████▎                                  | 314/800 [1:12:34<1:52:19, 13.87s/it, v_num=75]
# train_loss: tensor(14.8854, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  39%|██████████████████████▍                                  | 315/800 [1:12:47<1:52:04, 13.87s/it, v_num=75]
# train_loss: tensor(8.4566, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▌                                  | 316/800 [1:13:01<1:51:50, 13.86s/it, v_num=75]
# train_loss: tensor(14.9861, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▌                                  | 317/800 [1:13:14<1:51:36, 13.86s/it, v_num=75]
# train_loss: tensor(13.4969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▋                                  | 318/800 [1:13:28<1:51:21, 13.86s/it, v_num=75]
# train_loss: tensor(13.9236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▋                                  | 319/800 [1:13:42<1:51:07, 13.86s/it, v_num=75]
# train_loss: tensor(16.2881, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▊                                  | 320/800 [1:13:55<1:50:53, 13.86s/it, v_num=75]
# train_loss: tensor(12.7697, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▊                                  | 321/800 [1:14:09<1:50:39, 13.86s/it, v_num=75]
# train_loss: tensor(21.4791, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|██████████████████████▉                                  | 322/800 [1:14:23<1:50:25, 13.86s/it, v_num=75]
# train_loss: tensor(12.3581, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|███████████████████████                                  | 323/800 [1:14:36<1:50:11, 13.86s/it, v_num=75]
# train_loss: tensor(8.6273, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  40%|███████████████████████                                  | 324/800 [1:14:50<1:49:56, 13.86s/it, v_num=75]
# train_loss: tensor(22.3034, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▏                                 | 325/800 [1:15:04<1:49:42, 13.86s/it, v_num=75]
# train_loss: tensor(8.7752, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▏                                 | 326/800 [1:15:17<1:49:28, 13.86s/it, v_num=75]
# train_loss: tensor(15.3706, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▎                                 | 327/800 [1:15:31<1:49:14, 13.86s/it, v_num=75]
# train_loss: tensor(10.6761, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▎                                 | 328/800 [1:15:44<1:49:00, 13.86s/it, v_num=75]
# train_loss: tensor(8.5205, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▍                                 | 329/800 [1:15:58<1:48:46, 13.86s/it, v_num=75]
# train_loss: tensor(16.1270, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▌                                 | 330/800 [1:16:12<1:48:31, 13.86s/it, v_num=75]
# train_loss: tensor(9.0802, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  41%|███████████████████████▌                                 | 331/800 [1:16:25<1:48:17, 13.85s/it, v_num=75]
# train_loss: tensor(11.9091, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|███████████████████████▋                                 | 332/800 [1:16:40<1:48:04, 13.86s/it, v_num=75]
# train_loss: tensor(12.0029, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|███████████████████████▋                                 | 333/800 [1:16:53<1:47:50, 13.86s/it, v_num=75]
# train_loss: tensor(15.8436, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|███████████████████████▊                                 | 334/800 [1:17:08<1:47:37, 13.86s/it, v_num=75]
# train_loss: tensor(29.3012, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|███████████████████████▊                                 | 335/800 [1:17:22<1:47:23, 13.86s/it, v_num=75]
# train_loss: tensor(12.0979, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|███████████████████████▉                                 | 336/800 [1:17:35<1:47:09, 13.86s/it, v_num=75]
# train_loss: tensor(10.5828, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|████████████████████████                                 | 337/800 [1:17:49<1:46:55, 13.86s/it, v_num=75]
# train_loss: tensor(9.5606, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|████████████████████████                                 | 338/800 [1:18:03<1:46:41, 13.86s/it, v_num=75]
# train_loss: tensor(7.7424, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|████████████████████████▏                                | 339/800 [1:18:17<1:46:27, 13.86s/it, v_num=75]
# train_loss: tensor(9.6717, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  42%|████████████████████████▏                                | 340/800 [1:18:30<1:46:13, 13.86s/it, v_num=75]
# train_loss: tensor(10.5023, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▎                                | 341/800 [1:18:44<1:45:59, 13.85s/it, v_num=75]
# train_loss: tensor(8.1483, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▎                                | 342/800 [1:18:57<1:45:44, 13.85s/it, v_num=75]
# train_loss: tensor(13.4516, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▍                                | 343/800 [1:19:11<1:45:30, 13.85s/it, v_num=75]
# train_loss: tensor(13.9904, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▌                                | 344/800 [1:19:25<1:45:16, 13.85s/it, v_num=75]
# train_loss: tensor(38.6623, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▌                                | 345/800 [1:19:38<1:45:02, 13.85s/it, v_num=75]
# train_loss: tensor(9.6934, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▋                                | 346/800 [1:19:52<1:44:48, 13.85s/it, v_num=75]
# train_loss: tensor(9.9788, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  43%|████████████████████████▋                                | 347/800 [1:20:06<1:44:34, 13.85s/it, v_num=75]
# train_loss: tensor(11.0614, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|████████████████████████▊                                | 348/800 [1:20:19<1:44:20, 13.85s/it, v_num=75]
# train_loss: tensor(16.3510, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|████████████████████████▊                                | 349/800 [1:20:33<1:44:06, 13.85s/it, v_num=75]
# train_loss: tensor(11.6277, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|████████████████████████▉                                | 350/800 [1:20:46<1:43:51, 13.85s/it, v_num=75]
# train_loss: tensor(13.3465, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|█████████████████████████                                | 351/800 [1:21:00<1:43:37, 13.85s/it, v_num=75]
# train_loss: tensor(11.2789, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|█████████████████████████                                | 352/800 [1:21:14<1:43:23, 13.85s/it, v_num=75]
# train_loss: tensor(10.5665, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|█████████████████████████▏                               | 353/800 [1:21:27<1:43:09, 13.85s/it, v_num=75]
# train_loss: tensor(15.6431, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|█████████████████████████▏                               | 354/800 [1:21:41<1:42:55, 13.85s/it, v_num=75]
# train_loss: tensor(8.3261, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|█████████████████████████▎                               | 355/800 [1:21:56<1:42:42, 13.85s/it, v_num=75]
# train_loss: tensor(12.6729, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  44%|█████████████████████████▎                               | 356/800 [1:22:10<1:42:28, 13.85s/it, v_num=75]
# train_loss: tensor(14.4226, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▍                               | 357/800 [1:22:24<1:42:15, 13.85s/it, v_num=75]
# train_loss: tensor(10.5757, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▌                               | 358/800 [1:22:38<1:42:01, 13.85s/it, v_num=75]
# train_loss: tensor(6.7029, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▌                               | 359/800 [1:22:52<1:41:48, 13.85s/it, v_num=75]
# train_loss: tensor(9.7503, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▋                               | 360/800 [1:23:06<1:41:34, 13.85s/it, v_num=75]
# train_loss: tensor(27.8553, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▋                               | 361/800 [1:23:20<1:41:20, 13.85s/it, v_num=75]
# train_loss: tensor(15.4497, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▊                               | 362/800 [1:23:34<1:41:07, 13.85s/it, v_num=75]
# train_loss: tensor(8.8663, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  45%|█████████████████████████▊                               | 363/800 [1:23:48<1:40:53, 13.85s/it, v_num=75]
# train_loss: tensor(13.7576, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|█████████████████████████▉                               | 364/800 [1:24:02<1:40:40, 13.85s/it, v_num=75]
# train_loss: tensor(12.2820, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████                               | 365/800 [1:24:17<1:40:26, 13.85s/it, v_num=75]
# train_loss: tensor(19.3416, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████                               | 366/800 [1:24:31<1:40:13, 13.86s/it, v_num=75]
# train_loss: tensor(19.2855, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████▏                              | 367/800 [1:24:45<1:39:59, 13.86s/it, v_num=75]
# train_loss: tensor(8.6424, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████▏                              | 368/800 [1:24:59<1:39:45, 13.86s/it, v_num=75]
# train_loss: tensor(11.5087, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████▎                              | 369/800 [1:25:13<1:39:32, 13.86s/it, v_num=75]
# train_loss: tensor(15.8528, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████▎                              | 370/800 [1:25:27<1:39:18, 13.86s/it, v_num=75]
# train_loss: tensor(13.1815, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████▍                              | 371/800 [1:25:41<1:39:05, 13.86s/it, v_num=75]
# train_loss: tensor(14.7116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  46%|██████████████████████████▌                              | 372/800 [1:25:55<1:38:51, 13.86s/it, v_num=75]
# train_loss: tensor(9.9858, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|██████████████████████████▌                              | 373/800 [1:26:09<1:38:37, 13.86s/it, v_num=75]
# train_loss: tensor(12.1811, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|██████████████████████████▋                              | 374/800 [1:26:23<1:38:24, 13.86s/it, v_num=75]
# train_loss: tensor(13.8550, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|██████████████████████████▋                              | 375/800 [1:26:37<1:38:10, 13.86s/it, v_num=75]
# train_loss: tensor(13.0184, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|██████████████████████████▊                              | 376/800 [1:26:51<1:37:57, 13.86s/it, v_num=75]
# train_loss: tensor(9.4462, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|██████████████████████████▊                              | 377/800 [1:27:05<1:37:43, 13.86s/it, v_num=75]
# train_loss: tensor(11.3339, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|██████████████████████████▉                              | 378/800 [1:27:19<1:37:29, 13.86s/it, v_num=75]
# train_loss: tensor(8.7668, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  47%|███████████████████████████                              | 379/800 [1:27:33<1:37:16, 13.86s/it, v_num=75]
# train_loss: tensor(17.6615, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████                              | 380/800 [1:27:47<1:37:02, 13.86s/it, v_num=75]
# train_loss: tensor(14.2169, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▏                             | 381/800 [1:28:02<1:36:49, 13.86s/it, v_num=75]
# train_loss: tensor(17.7334, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▏                             | 382/800 [1:28:16<1:36:35, 13.86s/it, v_num=75]
# train_loss: tensor(11.6517, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▎                             | 383/800 [1:28:29<1:36:21, 13.86s/it, v_num=75]
# train_loss: tensor(15.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▎                             | 384/800 [1:28:43<1:36:07, 13.86s/it, v_num=75]
# train_loss: tensor(11.0673, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▍                             | 385/800 [1:28:57<1:35:52, 13.86s/it, v_num=75]
# train_loss: tensor(14.2027, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▌                             | 386/800 [1:29:10<1:35:38, 13.86s/it, v_num=75]
# train_loss: tensor(12.0888, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▌                             | 387/800 [1:29:24<1:35:24, 13.86s/it, v_num=75]
# train_loss: tensor(15.1972, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  48%|███████████████████████████▋                             | 388/800 [1:29:37<1:35:10, 13.86s/it, v_num=75]
# train_loss: tensor(25.5550, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|███████████████████████████▋                             | 389/800 [1:29:51<1:34:56, 13.86s/it, v_num=75]
# train_loss: tensor(12.8699, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|███████████████████████████▊                             | 390/800 [1:30:05<1:34:42, 13.86s/it, v_num=75]
# train_loss: tensor(8.1444, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|███████████████████████████▊                             | 391/800 [1:30:18<1:34:28, 13.86s/it, v_num=75]
# train_loss: tensor(15.5768, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|███████████████████████████▉                             | 392/800 [1:30:32<1:34:14, 13.86s/it, v_num=75]
# train_loss: tensor(8.4473, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|████████████████████████████                             | 393/800 [1:30:45<1:33:59, 13.86s/it, v_num=75]
# train_loss: tensor(14.6617, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|████████████████████████████                             | 394/800 [1:30:59<1:33:45, 13.86s/it, v_num=75]
# train_loss: tensor(11.5359, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  49%|████████████████████████████▏                            | 395/800 [1:31:13<1:33:31, 13.86s/it, v_num=75]
# train_loss: tensor(8.4536, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▏                            | 396/800 [1:31:26<1:33:17, 13.85s/it, v_num=75]
# train_loss: tensor(10.6280, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▎                            | 397/800 [1:31:40<1:33:03, 13.85s/it, v_num=75]
# train_loss: tensor(10.9890, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▎                            | 398/800 [1:31:53<1:32:49, 13.85s/it, v_num=75]
# train_loss: tensor(15.5173, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▍                            | 399/800 [1:32:07<1:32:35, 13.85s/it, v_num=75]
# train_loss: tensor(15.6448, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▌                            | 400/800 [1:32:21<1:32:21, 13.85s/it, v_num=75]
# train_loss: tensor(24.1578, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▌                            | 401/800 [1:32:35<1:32:08, 13.85s/it, v_num=75]
# train_loss: tensor(13.5582, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▋                            | 402/800 [1:32:49<1:31:54, 13.86s/it, v_num=75]
# train_loss: tensor(11.0327, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▋                            | 403/800 [1:33:03<1:31:40, 13.86s/it, v_num=75]
# train_loss: tensor(9.0428, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  50%|████████████████████████████▊                            | 404/800 [1:33:17<1:31:27, 13.86s/it, v_num=75]
# train_loss: tensor(8.6217, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|████████████████████████████▊                            | 405/800 [1:33:31<1:31:13, 13.86s/it, v_num=75]
# train_loss: tensor(11.6505, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|████████████████████████████▉                            | 406/800 [1:33:45<1:30:59, 13.86s/it, v_num=75]
# train_loss: tensor(13.9074, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|████████████████████████████▉                            | 407/800 [1:34:00<1:30:46, 13.86s/it, v_num=75]
# train_loss: tensor(6.8725, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|█████████████████████████████                            | 408/800 [1:34:13<1:30:32, 13.86s/it, v_num=75]
# train_loss: tensor(15.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|█████████████████████████████▏                           | 409/800 [1:34:27<1:30:18, 13.86s/it, v_num=75]
# train_loss: tensor(11.4357, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|█████████████████████████████▏                           | 410/800 [1:34:40<1:30:03, 13.86s/it, v_num=75]
# train_loss: tensor(9.8537, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  51%|█████████████████████████████▎                           | 411/800 [1:34:54<1:29:49, 13.86s/it, v_num=75]
# train_loss: tensor(9.1674, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▎                           | 412/800 [1:35:08<1:29:35, 13.85s/it, v_num=75]
# train_loss: tensor(7.6936, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▍                           | 413/800 [1:35:21<1:29:21, 13.85s/it, v_num=75]
# train_loss: tensor(11.3578, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▍                           | 414/800 [1:35:35<1:29:07, 13.85s/it, v_num=75]
# train_loss: tensor(14.5081, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▌                           | 415/800 [1:35:48<1:28:53, 13.85s/it, v_num=75]
# train_loss: tensor(12.5243, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▋                           | 416/800 [1:36:02<1:28:39, 13.85s/it, v_num=75]
# train_loss: tensor(12.8164, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▋                           | 417/800 [1:36:16<1:28:25, 13.85s/it, v_num=75]
# train_loss: tensor(30.2007, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▊                           | 418/800 [1:36:30<1:28:11, 13.85s/it, v_num=75]
# train_loss: tensor(10.2961, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▊                           | 419/800 [1:36:43<1:27:57, 13.85s/it, v_num=75]
# train_loss: tensor(21.6784, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  52%|█████████████████████████████▉                           | 420/800 [1:36:56<1:27:42, 13.85s/it, v_num=75]
# train_loss: tensor(12.2965, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|█████████████████████████████▉                           | 421/800 [1:37:10<1:27:28, 13.85s/it, v_num=75]
# train_loss: tensor(9.6627, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|██████████████████████████████                           | 422/800 [1:37:24<1:27:14, 13.85s/it, v_num=75]
# train_loss: tensor(13.9901, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|██████████████████████████████▏                          | 423/800 [1:37:37<1:27:00, 13.85s/it, v_num=75]
# train_loss: tensor(15.4236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|██████████████████████████████▏                          | 424/800 [1:37:51<1:26:46, 13.85s/it, v_num=75]
# train_loss: tensor(19.1834, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|██████████████████████████████▎                          | 425/800 [1:38:05<1:26:32, 13.85s/it, v_num=75]
# train_loss: tensor(9.3093, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|██████████████████████████████▎                          | 426/800 [1:38:18<1:26:18, 13.85s/it, v_num=75]
# train_loss: tensor(2.4236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  53%|██████████████████████████████▍                          | 427/800 [1:38:32<1:26:04, 13.85s/it, v_num=75]
# train_loss: tensor(13.2171, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▍                          | 428/800 [1:38:45<1:25:50, 13.85s/it, v_num=75]
# train_loss: tensor(11.6441, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▌                          | 429/800 [1:38:59<1:25:36, 13.84s/it, v_num=75]
# train_loss: tensor(16.4387, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▋                          | 430/800 [1:39:13<1:25:22, 13.84s/it, v_num=75]
# train_loss: tensor(10.8256, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▋                          | 431/800 [1:39:26<1:25:08, 13.84s/it, v_num=75]
# train_loss: tensor(12.0532, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▊                          | 432/800 [1:39:40<1:24:54, 13.84s/it, v_num=75]
# train_loss: tensor(12.0943, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▊                          | 433/800 [1:39:53<1:24:40, 13.84s/it, v_num=75]
# train_loss: tensor(17.3559, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▉                          | 434/800 [1:40:07<1:24:26, 13.84s/it, v_num=75]
# train_loss: tensor(13.7678, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  54%|██████████████████████████████▉                          | 435/800 [1:40:21<1:24:12, 13.84s/it, v_num=75]
# train_loss: tensor(10.8795, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████                          | 436/800 [1:40:34<1:23:58, 13.84s/it, v_num=75]
# train_loss: tensor(11.5594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▏                         | 437/800 [1:40:48<1:23:44, 13.84s/it, v_num=75]
# train_loss: tensor(21.0806, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▏                         | 438/800 [1:41:01<1:23:30, 13.84s/it, v_num=75]
# train_loss: tensor(22.4060, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▎                         | 439/800 [1:41:15<1:23:15, 13.84s/it, v_num=75]
# train_loss: tensor(14.4901, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▎                         | 440/800 [1:41:29<1:23:02, 13.84s/it, v_num=75]
# train_loss: tensor(18.7055, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▍                         | 441/800 [1:41:42<1:22:48, 13.84s/it, v_num=75]
# train_loss: tensor(16.6358, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▍                         | 442/800 [1:41:56<1:22:34, 13.84s/it, v_num=75]
# train_loss: tensor(14.6537, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  55%|███████████████████████████████▌                         | 443/800 [1:42:10<1:22:20, 13.84s/it, v_num=75]
# train_loss: tensor(8.3245, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|███████████████████████████████▋                         | 444/800 [1:42:23<1:22:06, 13.84s/it, v_num=75]
# train_loss: tensor(17.3250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|███████████████████████████████▋                         | 445/800 [1:42:37<1:21:52, 13.84s/it, v_num=75]
# train_loss: tensor(7.7784, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|███████████████████████████████▊                         | 446/800 [1:42:50<1:21:37, 13.84s/it, v_num=75]
# train_loss: tensor(9.5440, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|███████████████████████████████▊                         | 447/800 [1:43:04<1:21:24, 13.84s/it, v_num=75]
# train_loss: tensor(8.8767, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|███████████████████████████████▉                         | 448/800 [1:43:18<1:21:09, 13.84s/it, v_num=75]
# train_loss: tensor(14.7825, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|███████████████████████████████▉                         | 449/800 [1:43:31<1:20:56, 13.84s/it, v_num=75]
# train_loss: tensor(8.1724, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|████████████████████████████████                         | 450/800 [1:43:46<1:20:42, 13.84s/it, v_num=75]
# train_loss: tensor(10.8602, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|████████████████████████████████▏                        | 451/800 [1:43:59<1:20:28, 13.84s/it, v_num=75]
# train_loss: tensor(14.6925, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  56%|████████████████████████████████▏                        | 452/800 [1:44:13<1:20:14, 13.84s/it, v_num=75]
# train_loss: tensor(11.5336, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▎                        | 453/800 [1:44:27<1:20:00, 13.83s/it, v_num=75]
# train_loss: tensor(10.6005, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▎                        | 454/800 [1:44:40<1:19:46, 13.83s/it, v_num=75]
# train_loss: tensor(9.5028, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▍                        | 455/800 [1:44:54<1:19:32, 13.83s/it, v_num=75]
# train_loss: tensor(12.7519, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▍                        | 456/800 [1:45:07<1:19:18, 13.83s/it, v_num=75]
# train_loss: tensor(12.4754, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▌                        | 457/800 [1:45:21<1:19:04, 13.83s/it, v_num=75]
# train_loss: tensor(15.4068, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▋                        | 458/800 [1:45:35<1:18:50, 13.83s/it, v_num=75]
# train_loss: tensor(17.0627, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▋                        | 459/800 [1:45:48<1:18:36, 13.83s/it, v_num=75]
# train_loss: tensor(10.1368, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  57%|████████████████████████████████▊                        | 460/800 [1:46:02<1:18:22, 13.83s/it, v_num=75]
# train_loss: tensor(33.7154, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|████████████████████████████████▊                        | 461/800 [1:46:16<1:18:08, 13.83s/it, v_num=75]
# train_loss: tensor(12.4679, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|████████████████████████████████▉                        | 462/800 [1:46:29<1:17:54, 13.83s/it, v_num=75]
# train_loss: tensor(12.0334, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|████████████████████████████████▉                        | 463/800 [1:46:43<1:17:40, 13.83s/it, v_num=75]
# train_loss: tensor(22.7071, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|█████████████████████████████████                        | 464/800 [1:46:56<1:17:26, 13.83s/it, v_num=75]
# train_loss: tensor(10.8190, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|█████████████████████████████████▏                       | 465/800 [1:47:10<1:17:12, 13.83s/it, v_num=75]
# train_loss: tensor(19.2436, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|█████████████████████████████████▏                       | 466/800 [1:47:24<1:16:58, 13.83s/it, v_num=75]
# train_loss: tensor(9.8564, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|█████████████████████████████████▎                       | 467/800 [1:47:37<1:16:44, 13.83s/it, v_num=75]
# train_loss: tensor(13.2275, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  58%|█████████████████████████████████▎                       | 468/800 [1:47:51<1:16:31, 13.83s/it, v_num=75]
# train_loss: tensor(23.3587, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  59%|█████████████████████████████████▍                       | 469/800 [1:48:05<1:16:17, 13.83s/it, v_num=75]
# train_loss: tensor(15.8757, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  59%|█████████████████████████████████▍                       | 470/800 [1:48:20<1:16:04, 13.83s/it, v_num=75]
# train_loss: tensor(20.3280, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  59%|█████████████████████████████████▌                       | 471/800 [1:48:34<1:15:50, 13.83s/it, v_num=75]
# train_loss: tensor(10.1655, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  59%|█████████████████████████████████▋                       | 472/800 [1:48:48<1:15:36, 13.83s/it, v_num=75]
# train_loss: tensor(11.8272, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  59%|█████████████████████████████████▋                       | 473/800 [1:49:02<1:15:22, 13.83s/it, v_num=75]
# train_loss: tensor(17.7765, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:  59%|█████████████████████████████████▊                       | 474/800 [1:49:16<1:15:09, 13.83s/it, v_num=75]
# ...
# Epoch 4:  54%|██████████████████████████████▉                          | 434/800 [1:44:29<1:28:07, 14.45s/it, v_num=75]
# train_loss: tensor(8.3725, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  54%|██████████████████████████████▉                          | 435/800 [1:44:39<1:27:49, 14.44s/it, v_num=75]
# train_loss: tensor(15.5043, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████                          | 436/800 [1:44:51<1:27:32, 14.43s/it, v_num=75]
# train_loss: tensor(13.4970, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▏                         | 437/800 [1:45:02<1:27:14, 14.42s/it, v_num=75]
# train_loss: tensor(10.0340, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▏                         | 438/800 [1:45:12<1:26:57, 14.41s/it, v_num=75]
# train_loss: tensor(12.5986, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▎                         | 439/800 [1:45:39<1:26:53, 14.44s/it, v_num=75]
# train_loss: tensor(12.1923, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▎                         | 440/800 [1:46:06<1:26:49, 14.47s/it, v_num=75]
# train_loss: tensor(16.4832, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▍                         | 441/800 [1:46:33<1:26:44, 14.50s/it, v_num=75]
# train_loss: tensor(26.3977, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▍                         | 442/800 [1:47:11<1:26:49, 14.55s/it, v_num=75]
# train_loss: tensor(13.2501, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  55%|███████████████████████████████▌                         | 443/800 [1:47:41<1:26:47, 14.59s/it, v_num=75]
# train_loss: tensor(12.9045, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|███████████████████████████████▋                         | 444/800 [1:48:09<1:26:43, 14.62s/it, v_num=75]
# train_loss: tensor(13.9419, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|███████████████████████████████▋                         | 445/800 [1:48:36<1:26:38, 14.64s/it, v_num=75]
# train_loss: tensor(10.6074, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|███████████████████████████████▊                         | 446/800 [1:49:05<1:26:35, 14.68s/it, v_num=75]
# train_loss: tensor(19.9816, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|███████████████████████████████▊                         | 447/800 [1:49:35<1:26:32, 14.71s/it, v_num=75]
# train_loss: tensor(12.9961, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|███████████████████████████████▉                         | 448/800 [1:50:10<1:26:33, 14.76s/it, v_num=75]
# train_loss: tensor(12.0116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|███████████████████████████████▉                         | 449/800 [1:50:39<1:26:30, 14.79s/it, v_num=75]
# train_loss: tensor(11.3382, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|████████████████████████████████                         | 450/800 [1:51:11<1:26:28, 14.82s/it, v_num=75]
# train_loss: tensor(9.9847, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|████████████████████████████████▏                        | 451/800 [1:51:42<1:26:26, 14.86s/it, v_num=75]
# train_loss: tensor(24.8024, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  56%|████████████████████████████████▏                        | 452/800 [1:52:09<1:26:21, 14.89s/it, v_num=75]
# train_loss: tensor(12.4285, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▎                        | 453/800 [1:52:38<1:26:16, 14.92s/it, v_num=75]
# train_loss: tensor(11.9841, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▎                        | 454/800 [1:53:12<1:26:16, 14.96s/it, v_num=75]
# train_loss: tensor(11.0758, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▍                        | 455/800 [1:53:46<1:26:16, 15.00s/it, v_num=75]
# train_loss: tensor(12.2213, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▍                        | 456/800 [1:54:19<1:26:14, 15.04s/it, v_num=75]
# train_loss: tensor(13.6556, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▌                        | 457/800 [1:54:51<1:26:12, 15.08s/it, v_num=75]
# train_loss: tensor(19.3775, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▋                        | 458/800 [1:55:24<1:26:10, 15.12s/it, v_num=75]
# train_loss: tensor(20.6197, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▋                        | 459/800 [1:55:59<1:26:10, 15.16s/it, v_num=75]
# train_loss: tensor(23.2253, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  57%|████████████████████████████████▊                        | 460/800 [1:56:32<1:26:08, 15.20s/it, v_num=75]
# train_loss: tensor(13.3144, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|████████████████████████████████▊                        | 461/800 [1:57:08<1:26:08, 15.25s/it, v_num=75]
# train_loss: tensor(20.5378, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|████████████████████████████████▉                        | 462/800 [1:57:41<1:26:06, 15.28s/it, v_num=75]
# train_loss: tensor(13.3778, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|████████████████████████████████▉                        | 463/800 [1:58:16<1:26:05, 15.33s/it, v_num=75]
# train_loss: tensor(15.3024, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|█████████████████████████████████                        | 464/800 [1:58:49<1:26:02, 15.36s/it, v_num=75]
# train_loss: tensor(9.7962, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|█████████████████████████████████▏                       | 465/800 [1:59:22<1:26:00, 15.40s/it, v_num=75]
# train_loss: tensor(13.0857, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|█████████████████████████████████▏                       | 466/800 [1:59:58<1:25:59, 15.45s/it, v_num=75]
# train_loss: tensor(19.8335, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|█████████████████████████████████▎                       | 467/800 [2:00:31<1:25:56, 15.49s/it, v_num=75]
# train_loss: tensor(7.5614, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  58%|█████████████████████████████████▎                       | 468/800 [2:01:04<1:25:53, 15.52s/it, v_num=75]
# train_loss: tensor(8.3298, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▍                       | 469/800 [2:01:36<1:25:49, 15.56s/it, v_num=75]
# train_loss: tensor(14.5768, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▍                       | 470/800 [2:02:09<1:25:46, 15.60s/it, v_num=75]
# train_loss: tensor(13.3292, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▌                       | 471/800 [2:02:43<1:25:43, 15.63s/it, v_num=75]
# train_loss: tensor(14.0829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▋                       | 472/800 [2:03:32<1:25:51, 15.71s/it, v_num=75]
# train_loss: tensor(8.2831, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▋                       | 473/800 [2:04:09<1:25:50, 15.75s/it, v_num=75]
# train_loss: tensor(8.7801, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▊                       | 474/800 [2:04:48<1:25:50, 15.80s/it, v_num=75]
# train_loss: tensor(9.9947, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  59%|█████████████████████████████████▊                       | 475/800 [2:05:24<1:25:48, 15.84s/it, v_num=75]
# train_loss: tensor(14.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|█████████████████████████████████▉                       | 476/800 [2:06:19<1:25:59, 15.92s/it, v_num=75]
# train_loss: tensor(8.8923, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|█████████████████████████████████▉                       | 477/800 [2:06:55<1:25:56, 15.97s/it, v_num=75]
# train_loss: tensor(15.5364, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████                       | 478/800 [2:07:31<1:25:54, 16.01s/it, v_num=75]
# train_loss: tensor(11.8197, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████▏                      | 479/800 [2:08:09<1:25:53, 16.05s/it, v_num=75]
# train_loss: tensor(14.6219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████▏                      | 480/800 [2:08:46<1:25:50, 16.10s/it, v_num=75]
# train_loss: tensor(15.0137, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████▎                      | 481/800 [2:09:24<1:25:49, 16.14s/it, v_num=75]
# train_loss: tensor(18.3738, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████▎                      | 482/800 [2:09:58<1:25:44, 16.18s/it, v_num=75]
# train_loss: tensor(11.3074, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████▍                      | 483/800 [2:11:02<1:26:00, 16.28s/it, v_num=75]
# train_loss: tensor(18.0293, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  60%|██████████████████████████████████▍                      | 484/800 [2:11:39<1:25:57, 16.32s/it, v_num=75]
# train_loss: tensor(12.9909, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▌                      | 485/800 [2:12:17<1:25:55, 16.37s/it, v_num=75]
# train_loss: tensor(20.3208, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▋                      | 486/800 [2:13:22<1:26:10, 16.47s/it, v_num=75]
# train_loss: tensor(30.2488, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▋                      | 487/800 [2:14:00<1:26:07, 16.51s/it, v_num=75]
# train_loss: tensor(12.4050, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▊                      | 488/800 [2:15:12<1:26:26, 16.62s/it, v_num=75]
# train_loss: tensor(14.5190, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▊                      | 489/800 [2:15:51<1:26:24, 16.67s/it, v_num=75]
# train_loss: tensor(12.7475, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▉                      | 490/800 [2:16:29<1:26:21, 16.71s/it, v_num=75]
# train_loss: tensor(34.0236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  61%|██████████████████████████████████▉                      | 491/800 [2:17:44<1:26:41, 16.83s/it, v_num=75]
# train_loss: tensor(15.5958, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████                      | 492/800 [2:18:24<1:26:38, 16.88s/it, v_num=75]
# train_loss: tensor(17.2021, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▏                     | 493/800 [2:19:02<1:26:34, 16.92s/it, v_num=75]
# train_loss: tensor(12.9024, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▏                     | 494/800 [2:19:43<1:26:33, 16.97s/it, v_num=75]
# train_loss: tensor(18.7840, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▎                     | 495/800 [2:20:23<1:26:29, 17.02s/it, v_num=75]
# train_loss: tensor(12.5386, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▎                     | 496/800 [2:21:05<1:26:28, 17.07s/it, v_num=75]
# train_loss: tensor(19.1369, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▍                     | 497/800 [2:21:44<1:26:24, 17.11s/it, v_num=75]
# train_loss: tensor(14.7200, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▍                     | 498/800 [2:22:34<1:26:27, 17.18s/it, v_num=75]
# train_loss: tensor(15.7178, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▌                     | 499/800 [2:27:40<1:29:05, 17.76s/it, v_num=75]
# train_loss: tensor(18.7370, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  62%|███████████████████████████████████▋                     | 500/800 [2:28:22<1:29:01, 17.80s/it, v_num=75]
# train_loss: tensor(13.8262, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|███████████████████████████████████▋                     | 501/800 [2:28:52<1:28:50, 17.83s/it, v_num=75]
# train_loss: tensor(16.7286, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|███████████████████████████████████▊                     | 502/800 [2:29:21<1:28:39, 17.85s/it, v_num=75]
# train_loss: tensor(16.3412, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|███████████████████████████████████▊                     | 503/800 [2:29:50<1:28:28, 17.87s/it, v_num=75]
# train_loss: tensor(8.1682, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|███████████████████████████████████▉                     | 504/800 [2:30:26<1:28:21, 17.91s/it, v_num=75]
# train_loss: tensor(12.1757, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|███████████████████████████████████▉                     | 505/800 [2:30:55<1:28:10, 17.93s/it, v_num=75]
# train_loss: tensor(15.5562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|████████████████████████████████████                     | 506/800 [2:31:24<1:27:58, 17.95s/it, v_num=75]
# train_loss: tensor(33.4771, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  63%|████████████████████████████████████                     | 507/800 [2:31:59<1:27:50, 17.99s/it, v_num=75]
# train_loss: tensor(18.6546, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▏                    | 508/800 [2:32:29<1:27:39, 18.01s/it, v_num=75]
# train_loss: tensor(10.1739, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▎                    | 509/800 [2:33:00<1:27:28, 18.04s/it, v_num=75]
# train_loss: tensor(14.1679, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▎                    | 510/800 [2:33:29<1:27:16, 18.06s/it, v_num=75]
# train_loss: tensor(23.7914, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▍                    | 511/800 [2:34:00<1:27:06, 18.08s/it, v_num=75]
# train_loss: tensor(13.4115, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▍                    | 512/800 [2:34:28<1:26:53, 18.10s/it, v_num=75]
# train_loss: tensor(13.4334, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▌                    | 513/800 [2:35:01<1:26:43, 18.13s/it, v_num=75]
# train_loss: tensor(18.2259, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▌                    | 514/800 [2:35:34<1:26:33, 18.16s/it, v_num=75]
# train_loss: tensor(10.9633, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▋                    | 515/800 [2:36:04<1:26:22, 18.18s/it, v_num=75]
# train_loss: tensor(12.8863, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  64%|████████████████████████████████████▊                    | 516/800 [2:36:35<1:26:11, 18.21s/it, v_num=75]
# train_loss: tensor(10.5730, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  65%|████████████████████████████████████▊                    | 517/800 [2:37:03<1:25:58, 18.23s/it, v_num=75]
# train_loss: tensor(11.2173, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:  65%|████████████████████████████████████▉                    | 518/800 [2:37:26<1:25:42, 18.24s/it, v_num=75]
# train_loss:

# %%
import torch

def save_tensor(tensor, filepath):
    torch.save(tensor, filepath)

# %%
# Supongamos que 'model' es tu modelo entrenado
torch.save(model2, 'C:\\ProyectoLibertad\\autoencoder\\checkpoints\\autoencoder_last.ckpt')

# %%
# Primero, debes crear una instancia del mismo tipo de modelo
model2 = AutoEncoderModule()

# Luego, puedes cargar los parámetros del modelo
#model2.load_state_dict(torch.load('C:\\ProyectoLibertad\\autoencoder\\checkpoints\\autoencoder-epoch=09-val_loss=198.90.ckpt'))
checkpoint = torch.load('C:\\ProyectoLibertad\\autoencoder\\checkpoints\\autoencoder-epoch=02-val_loss=14.87.ckpt')
model2.load_state_dict(checkpoint['state_dict'])


# Asegúrate de llamar a model.eval() antes de hacer inferencias
#model2.eval()
# Out:
# <All keys matched successfully>

# %%
model2.eval()
__sinewave__ = test_dataset.__getitem__(0)
torchaudio.save('C:\\ProyectoLibertad\\autoencoder\\validations\\6.wav', __sinewave__, 22050)
__sinewave__.shape
__sinewave__ = __sinewave__.unsqueeze(0)
__sinewave__.shape
__result__ = model2.autoencoder(__sinewave__)
__encoded__ = model2.autoencoder.encode(__sinewave__)
print("ENCODED SHAPE: ", __encoded__.shape)
__result__.shape
__result__ = __result__.squeeze(0)
__result__ = __result__.detach()
__result__ = __result__.sum(dim=0, keepdim=True)
torchaudio.save('C:\\ProyectoLibertad\\autoencoder\\validations\\6_gen.wav', __result__, 22050)
# Out:
# ENCODED SHAPE:  torch.Size([256, 1, 124032])

# %%
__encoded__.shape
#torch.save(__encoded__, "C:\\ProyectoLibertad\\autoencoder\\encodeds\\tensor.bbb")
# Out:
# torch.Size([256, 1, 124032])

# %%
#__result__.shape
mono_tensor = __result__.sum(dim=0, keepdim=True)
mono_tensor.shape
mono_tensor_numpy = mono_tensor.cpu().detach().numpy()
#visualize_sinewave(mono_tensor_numpy)

bii = 2394
torchaudio.save('C:\\ProyectoLibertad\\autoencoder\\validations\\{}_gen.wav'.format(bii), mono_tensor, 22050)
#visualize_sinewave(mono_tensor)
